# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("s .csv")

# Display first 10 rows
print(df.head(10))

# Get dataset information
print(df.info())

# Check for missing values
print(df.isnull())
